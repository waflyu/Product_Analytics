# %%
import pandas as pd
from scipy import stats 

print("A/B тест")
# Out:
# A/B тест

# %%
data = pd.DataFrame({
    "group": [
        "A","A","A","A","A",
        "B","B","B","B","B"
    ],
    "started_course": [
        0,1,0,1,0,
        1,1,0,1,1
    ]
})

data
# Out:
#   group  started_course
# 0     A               0
# 1     A               1
# 2     A               0
# 3     A               1
# 4     A               0
# 5     B               1
# 6     B               1
# 7     B               0
# 8     B               1
# 9     B               1

# %%
conversion = data.groupby("group")["started_course"].mean() * 100

print(conversion)
# Out:
# group
# A    40.0
# B    80.0
# Name: started_course, dtype: float64

# %%
print("""
Вывод:

Группа B показала более высокую конверсию начала курса.
Новая версия интерфейса потенциально улучшает первый пользовательский опыт.

Для принятия окончательного решения необходимо провести тест
на большей выборке пользователей.
""")
# Out:
# Вывод:
#
# Группа B показала более высокую конверсию начала курса.
# Новая версия интерфейса потенциально улучшает первый пользовательский опыт.
#
# Для принятия окончательного решения необходимо провести тест
# на большей выборке пользователей.
